# %%
import os.path as op
import random
import pandas as pd
import torch
from torch.utils.data import Dataset, DataLoader

class MovielensData(Dataset):
    def __init__(self, data_dir=r'data/ref/movielens',
                 stage=None,
                 cans_num=10,
                 sep=", ",
                 no_augment=True):
        self.__dict__.update(locals())
        self.aug = (stage == 'train') and not no_augment
        self.padding_item_id = 4606
        self.padding_rating = 0
        self.check_files()

    def __len__(self):
        return len(self.session_data['seq'])

    def __getitem__(self, i):
        temp = self.session_data.iloc[i]
        candidates = self.negative_sampling(temp['seq_unpad'], temp['next'])
        cans_name = [self.item_id2name.get(can, "Unknown") for can in candidates]
        sample = {
            'seq': temp['seq'],
            'seq_name': temp['seq_title'],
            'len_seq': temp['len_seq'],
            'seq_str': self.sep.join(temp['seq_title']),
            'cans': candidates,
            'cans_name': cans_name,
            'cans_str': self.sep.join(cans_name),
            'len_cans': self.cans_num,
            'item_id': temp['next'],
            'item_name': temp['next_item_name'],
            'correct_answer': temp['next_item_name'],
            'most_similar_seq': temp['most_similar_seq'],
            'most_similar_seq_next': temp['most_similar_seq_next'],
            'most_similar_seq_name': temp['most_similar_seq_name'],
            'most_similar_seq_next_name': temp['most_similar_seq_next_name'],
        }
        return sample

    def negative_sampling(self, seq_unpad, next_item):
        canset = [i for i in list(self.item_id2name.keys()) if i not in seq_unpad and i != next_item]
        candidates = random.sample(canset, self.cans_num - 1) + [next_item]
        random.shuffle(candidates)
        return candidates

    def check_files(self):
        self.item_id2name = self.get_movie_id2name()
        if self.stage == 'train':
            filename = "similar_train_data.df"
        elif self.stage == 'val':
            filename = "similar_val_data.df"
        elif self.stage == 'test':
            filename = "similar_test_data.df"
        data_path = op.join(self.data_dir, filename)
        self.session_data = self.session_data4frame(data_path, self.item_id2name)

    def get_mv_title(self, s):
        sub_list = [", The", ", A", ", An"]
        for sub_s in sub_list:
            if sub_s in s:
                return sub_s[2:] + " " + s.replace(sub_s, "")
        return s

    def get_movie_id2name(self):
        movie_id2name = dict()
        item_path = op.join(self.data_dir, 'id2name.txt')
        with open(item_path, 'r') as f:
            for l in f.readlines():
                ll = l.strip('\n').split('::')
                movie_id2name[int(ll[0])] = ll[1].strip()
        return movie_id2name

    def session_data4frame(self, datapath, movie_id2name):
        print(f"Loading data from {datapath}\n")
        train_data = pd.read_pickle(datapath)
        print("Initial train_data loaded\n")
        print(train_data.head(), "\n")
        train_data = train_data[train_data['len_seq'] >= 3]

        def remove_padding(xx):
            x = xx[:]
            for i in range(10):
                try:
                    x.remove(self.padding_item_id)
                except ValueError:
                    break
            return x

        train_data['seq_unpad'] = train_data['seq'].apply(remove_padding)
        print("Padding removed\n")
        print(train_data[['seq', 'seq_unpad']].head(), "\n")

        def seq_to_title(x):
            titles = []
            for x_i in x:
                if x_i in movie_id2name:
                    titles.append(movie_id2name[x_i])
                else:
                    print(f"KeyError: Movie ID {x_i} not found in movie_id2name.\n")
                    titles.append("Unknown")
            return titles

        train_data['seq_title'] = train_data['seq_unpad'].apply(seq_to_title)
        print("Titles added\n")
        print(train_data[['seq_unpad', 'seq_title']].head(), "\n")

        def next_item_title(x):
            if x in movie_id2name:
                return movie_id2name[x]
            else:
                print(f"KeyError: Movie ID {x} not found in movie_id2name.\n")
                return "Unknown"

        train_data['next_item_name'] = train_data['next'].apply(next_item_title)
        print("Next item titles added\n")
        print(train_data[['next', 'next_item_name']].head(), "\n")

        def get_id(x):
            if isinstance(x, tuple):
                return x[0]
            return x

        def get_id_list(x):
            if isinstance(x[0], tuple):
                return [i[0] for i in x]
            return x

        train_data['next'] = train_data['next'].apply(get_id)
        train_data['seq'] = train_data['seq'].apply(get_id_list)
        train_data['seq_unpad'] = train_data['seq_unpad'].apply(get_id_list)
        train_data['most_similar_seq_next'] = train_data['most_similar_seq_next'].apply(get_id)
        train_data['most_similar_seq'] = train_data['most_similar_seq'].apply(get_id)
        print("IDs converted\n")
        print(train_data.head(), "\n")

        return train_data

# 假设数据目录和阶段已经被正确设置
dataset = MovielensData(data_dir='/workspace/LLaRA/data/ref/movielens', stage='train')
dataloader = DataLoader(dataset, batch_size=1, shuffle=True)  # 设置批量大小为1

# 获取一个批次的数据并打印
for batch in dataloader:
    print(batch, "\n")
    break  # 只打印第一个批次

# Add logging in the training loop
def train_model(dataloader):
    for i, batch in enumerate(dataloader):
        print(f"Batch {i}: {batch}\n")
        break  # 只打印一个批次的数据

# Train the model and debug
train_model(dataloader)
# Out:
# Loading data from /workspace/LLaRA/data/ref/movielens/similar_train_data.df
#
# Initial train_data loaded
#
#                                                  seq  len_seq  next  \
# 0  [4606, 4606, 4606, 4606, 4606, 4606, 4606, 460...        1     0
# 1  [0, 4606, 4606, 4606, 4606, 4606, 4606, 4606, ...        1     1
# 2  [0, 1, 4606, 4606, 4606, 4606, 4606, 4606, 460...        2     2
# 3  [0, 1, 2, 4606, 4606, 4606, 4606, 4606, 4606, ...        3     3
# 4   [0, 1, 2, 3, 4606, 4606, 4606, 4606, 4606, 4606]        4     4
#
#                                     movie_names_only  \
# 0  [4606, 4606, 4606, 4606, 4606, 4606, 4606, 460...
# 1  [Morcheeba, 4606, 4606, 4606, 4606, 4606, 4606...
# 2  [Morcheeba, Enigma, 4606, 4606, 4606, 4606, 46...
# 3  [Morcheeba, Enigma, CafÃ© Del Mar, 4606, 4606,...
# 4  [Morcheeba, Enigma, CafÃ© Del Mar, Fleetwood M...
#
#                               most_similar_seq_index  \
# 0  [18110.0, 17948.0, 40368.0, 17925.0, 17921.0, ...
# 1  [48119.0, 1594.0, 14383.0, 26558.0, 47437.0, 2...
# 2  [1594.0, 32034.0, 42247.0, 35457.0, 26155.0, 3...
# 3  [40147.0, 41212.0, 4321.0, 35457.0, 42247.0, 1...
# 4  [40147.0, 41212.0, 4321.0, 444.0, 445.0, 38345...
#
#                                     most_similar_seq  \
# 0  [[4606, 4606, 4606, 4606, 4606, 4606, 4606, 46...
# 1  [[855, 4606, 4606, 4606, 4606, 4606, 4606, 460...
# 2  [[1354, 4606, 4606, 4606, 4606, 4606, 4606, 46...
# 3  [[202, 396, 4606, 4606, 4606, 4606, 4606, 4606...
# 4  [[202, 396, 4606, 4606, 4606, 4606, 4606, 4606...
#
#                                most_similar_seq_next  \
# 0  [2321, 631, 20, 842, 2414, 1194, 668, 1287, 63...
# 1  [3501, 555, 251, 252, 1363, 63, 224, 1804, 180...
# 2   [555, 3876, 632, 1, 208, 12, 63, 1804, 632, 251]
# 3  [205, 632, 2277, 1, 632, 1998, 555, 1058, 3908...
# 4  [205, 632, 2277, 14, 37, 632, 634, 177, 1663, ...
#
#                                most_similar_seq_name  \
# 0  [[Unknown, Unknown, Unknown, Unknown, Unknown,...
# 1  [[Yeah Yeah Yeahs, Unknown, Unknown, Unknown, ...
# 2  [[Sam Cooke, Unknown, Unknown, Unknown, Unknow...
# 3  [[Goldfrapp, New Order, Unknown, Unknown, Unkn...
# 4  [[Goldfrapp, New Order, Unknown, Unknown, Unkn...
#
#                           most_similar_seq_next_name
# 0  [Maria BethÃ¢nia, Marilyn Manson, Michael Jack...
# 1  [Broken Social Scene, Pearl Jam, Anathema, Sao...
# 2  [Pearl Jam, Gil Scott-Heron, Coldplay, Enigma,...
# 3  [Gorillaz, Coldplay, Kelis, Enigma, Coldplay, ...
# 4  [Gorillaz, Coldplay, Kelis, INXS, Tears for Fe...
#
# Padding removed
#
#                                                  seq              seq_unpad
# 3  [0, 1, 2, 4606, 4606, 4606, 4606, 4606, 4606, ...              [0, 1, 2]
# 4   [0, 1, 2, 3, 4606, 4606, 4606, 4606, 4606, 4606]           [0, 1, 2, 3]
# 5      [0, 1, 2, 3, 4, 4606, 4606, 4606, 4606, 4606]        [0, 1, 2, 3, 4]
# 6         [0, 1, 2, 3, 4, 5, 4606, 4606, 4606, 4606]     [0, 1, 2, 3, 4, 5]
# 7            [0, 1, 2, 3, 4, 5, 6, 4606, 4606, 4606]  [0, 1, 2, 3, 4, 5, 6]
#
# Titles added
#
#                seq_unpad                                          seq_title
# 3              [0, 1, 2]                  [Morcheeba, Enigma, Café Del Mar]
# 4           [0, 1, 2, 3]   [Morcheeba, Enigma, Café Del Mar, Fleetwood Mac]
# 5        [0, 1, 2, 3, 4]  [Morcheeba, Enigma, Café Del Mar, Fleetwood Ma...
# 6     [0, 1, 2, 3, 4, 5]  [Morcheeba, Enigma, Café Del Mar, Fleetwood Ma...
# 7  [0, 1, 2, 3, 4, 5, 6]  [Morcheeba, Enigma, Café Del Mar, Fleetwood Ma...
#
# Next item titles added
#
#    next       next_item_name
# 3     3        Fleetwood Mac
# 4     4         China Crisis
# 5     5               Loscil
# 6     6              Chicane
# 7     7  Sigue Sigue Sputnik
#
# IDs converted
#
#                                                  seq  len_seq  next  \
# 3  [0, 1, 2, 4606, 4606, 4606, 4606, 4606, 4606, ...        3     3
# 4   [0, 1, 2, 3, 4606, 4606, 4606, 4606, 4606, 4606]        4     4
# 5      [0, 1, 2, 3, 4, 4606, 4606, 4606, 4606, 4606]        5     5
# 6         [0, 1, 2, 3, 4, 5, 4606, 4606, 4606, 4606]        6     6
# 7            [0, 1, 2, 3, 4, 5, 6, 4606, 4606, 4606]        7     7
#
#                                     movie_names_only  \
# 3  [Morcheeba, Enigma, CafÃ© Del Mar, 4606, 4606,...
# 4  [Morcheeba, Enigma, CafÃ© Del Mar, Fleetwood M...
# 5  [Morcheeba, Enigma, CafÃ© Del Mar, Fleetwood M...
# 6  [Morcheeba, Enigma, CafÃ© Del Mar, Fleetwood M...
# 7  [Morcheeba, Enigma, CafÃ© Del Mar, Fleetwood M...
#
#                               most_similar_seq_index  \
# 3  [40147.0, 41212.0, 4321.0, 35457.0, 42247.0, 1...
# 4  [40147.0, 41212.0, 4321.0, 444.0, 445.0, 38345...
# 5  [4.0, 40147.0, 41212.0, 26841.0, 31366.0, 3834...
# 6  [5.0, 4.0, 7.0, 43090.0, 17552.0, 26842.0, 430...
# 7  [48054.0, 48545.0, 48544.0, 45413.0, 6.0, 4541...
#
#                                     most_similar_seq  \
# 3  [[202, 396, 4606, 4606, 4606, 4606, 4606, 4606...
# 4  [[202, 396, 4606, 4606, 4606, 4606, 4606, 4606...
# 5  [[0, 1, 2, 3, 4606, 4606, 4606, 4606, 4606, 46...
# 6  [[0, 1, 2, 3, 4, 4606, 4606, 4606, 4606, 4606]...
# 7  [[1401, 3747, 4276, 3433, 3434, 4532, 3569, 18...
#
#                                most_similar_seq_next  \
# 3  [205, 632, 2277, 1, 632, 1998, 555, 1058, 3908...
# 4  [205, 632, 2277, 14, 37, 632, 634, 177, 1663, ...
# 5   [4, 205, 632, 2288, 1663, 632, 37, 14, 2277, 18]
# 6      [5, 4, 7, 2720, 904, 16, 557, 2276, 64, 1288]
# 7  [1621, 3326, 4446, 2136, 6, 1110, 4121, 2535, ...
#
#                                most_similar_seq_name  \
# 3  [[Goldfrapp, New Order, Unknown, Unknown, Unkn...
# 4  [[Goldfrapp, New Order, Unknown, Unknown, Unkn...
# 5  [[Morcheeba, Enigma, CafÃ© Del Mar, Fleetwood ...
# 6  [[Morcheeba, Enigma, CafÃ© Del Mar, Fleetwood ...
# 7  [[Vangelis, Kaya Project, Ott, All My Faith Lo...
#
#                           most_similar_seq_next_name              seq_unpad  \
# 3  [Gorillaz, Coldplay, Kelis, Enigma, Coldplay, ...              [0, 1, 2]
# 4  [Gorillaz, Coldplay, Kelis, INXS, Tears for Fe...           [0, 1, 2, 3]
# 5  [China Crisis, Gorillaz, Coldplay, The Notwist...        [0, 1, 2, 3, 4]
# 6  [Loscil, China Crisis, Sigue Sigue Sputnik, PJ...     [0, 1, 2, 3, 4, 5]
# 7  [Loreena McKennitt, Kruder & Dorfmeister, Harl...  [0, 1, 2, 3, 4, 5, 6]
#
#                                            seq_title       next_item_name
# 3                  [Morcheeba, Enigma, Café Del Mar]        Fleetwood Mac
# 4   [Morcheeba, Enigma, Café Del Mar, Fleetwood Mac]         China Crisis
# 5  [Morcheeba, Enigma, Café Del Mar, Fleetwood Ma...               Loscil
# 6  [Morcheeba, Enigma, Café Del Mar, Fleetwood Ma...              Chicane
# 7  [Morcheeba, Enigma, Café Del Mar, Fleetwood Ma...  Sigue Sigue Sputnik
#
# {'seq': [tensor([229]), tensor([672]), tensor([183]), tensor([1210]), tensor([39]), tensor([238]), tensor([116]), tensor([256]), tensor([860]), tensor([862])], 'seq_name': [('Akira Yamaoka',), ('She Wants Revenge',), ('Backstreet Boys',), ('*NSYNC',), ('Savage Garden',), ('The Birthday Massacre',), ('HIM',), ('U2',), ('Gwen Stefani',), ('Alphabeat',)], 'len_seq': tensor([10]), 'seq_str': ['Akira Yamaoka, She Wants Revenge, Backstreet Boys, *NSYNC, Savage Garden, The Birthday Massacre, HIM, U2, Gwen Stefani, Alphabeat'], 'cans': [tensor([3626]), tensor([1161]), tensor([1212]), tensor([274]), tensor([2293]), tensor([3267]), tensor([268]), tensor([2599]), tensor([1044]), tensor([1257])], 'cans_name': [('The Get Up Kids',), ('Trevor Rabin',), ('No Doubt',), ('#####',), ('Lali Puna',), ('Nicola Conte',), ('Maroon 5',), ('Persuader',), ('Die Ärzte',), ('Kenny Chesney',)], 'cans_str': ['The Get Up Kids, Trevor Rabin, No Doubt, #####, Lali Puna, Nicola Conte, Maroon 5, Persuader, Die Ärzte, Kenny Chesney'], 'len_cans': tensor([10]), 'item_id': tensor([1212]), 'item_name': ['No Doubt'], 'correct_answer': ['No Doubt'], 'most_similar_seq': [[tensor([2022]), tensor([190]), tensor([576]), tensor([875]), tensor([577]), tensor([2023]), tensor([1365]), tensor([542]), tensor([121]), tensor([1223])], [tensor([39]), tensor([2630]), tensor([2025]), tensor([708]), tensor([510]), tensor([2631]), tensor([1292]), tensor([716]), tensor([2632]), tensor([1225])], [tensor([39]), tensor([501]), tensor([859]), tensor([246]), tensor([860]), tensor([863]), tensor([268]), tensor([190]), tensor([867]), tensor([1362])], [tensor([173]), tensor([2021]), tensor([183]), tensor([500]), tensor([39]), tensor([501]), tensor([859]), tensor([246]), tensor([860]), tensor([863])], [tensor([1571]), tensor([1017]), tensor([1576]), tensor([150]), tensor([1865]), tensor([346]), tensor([3090]), tensor([1026]), tensor([3091]), tensor([1578])], [tensor([672]), tensor([183]), tensor([1210]), tensor([39]), tensor([238]), tensor([116]), tensor([256]), tensor([860]), tensor([862]), tensor([1212])], [tensor([1017]), tensor([1576]), tensor([150]), tensor([1865]), tensor([346]), tensor([3090]), tensor([1026]), tensor([3091]), tensor([1578]), tensor([1579])], [tensor([2443]), tensor([1042]), tensor([1401]), tensor([447]), tensor([1046]), tensor([4559]), tensor([771]), tensor([3712]), tensor([1874]), tensor([3343])], [tensor([203]), tensor([12]), tensor([1466]), tensor([206]), tensor([834]), tensor([840]), tensor([210]), tensor([172]), tensor([398]), tensor([399])], [tensor([2193]), tensor([3110]), tensor([3357]), tensor([3735]), tensor([1128]), tensor([3388]), tensor([1629]), tensor([1632]), tensor([4282]), tensor([3666])]], 'most_similar_seq_next': [tensor([1976]), tensor([2633]), tensor([402]), tensor([268]), tensor([1579]), tensor([190]), tensor([1027]), tensor([3681]), tensor([863]), tensor([1635])], 'most_similar_seq_name': [[('Little Boots',), ('Fall Out Boy',), ('Glee Cast',), ('The Veronicas',), ('All Time Low',), ('Hey Monday',), ('Hannah Montana',), ('Girls Aloud',), ('Nickelback',), ('Boys Like Girls',)], [('Savage Garden',), ('Westlife',), ('Capital Inicial',), ('ATB',), ('Atomic Kitten',), ('Five',), ("Destiny's Child",), ('Groove Coverage',), ('Jamal',), ('Ace of Base',)], [('Savage Garden',), ('Jessica Simpson',), ('3 Doors Down',), ('Flyleaf',), ('Gwen Stefani',), ('Oasis',), ('Maroon 5',), ('Fall Out Boy',), ('The Kinks',), ('The Who',)], [('Kate Nash',), ('Silverchair',), ('Backstreet Boys',), ('Blue',), ('Savage Garden',), ('Jessica Simpson',), ('3 Doors Down',), ('Flyleaf',), ('Gwen Stefani',), ('Oasis',)], [('The Adicts',), ('Carole King',), ('Ugly Kid Joe',), ('Saliva',), ('Sara Evans',), ('Brand New',), ('Girl Talk',), ('Soulfly',), ('Spinnerette',), ('Hole',)], [('She Wants Revenge',), ('Backstreet Boys',), ('*NSYNC',), ('Savage Garden',), ('The Birthday Massacre',), ('HIM',), ('U2',), ('Gwen Stefani',), ('Alphabeat',), ('No Doubt',)], [('Carole King',), ('Ugly Ki ...
#
# Batch 0: {'seq': [tensor([2749]), tensor([1877]), tensor([3058]), tensor([3059]), tensor([2840]), tensor([1878]), tensor([1879]), tensor([3060]), tensor([1068]), tensor([3061])], 'seq_name': [('Sun City Girls',), ('Hank Williams',), ('The Flying Burrito Brothers',), ('Loretta Lynn',), ('The Band',), ('Willie Nelson',), ('Emmylou Harris',), ('Hawkwind',), ('Yo La Tengo',), ('Leadbelly',)], 'len_seq': tensor([10]), 'seq_str': ['Sun City Girls, Hank Williams, The Flying Burrito Brothers, Loretta Lynn, The Band, Willie Nelson, Emmylou Harris, Hawkwind, Yo La Tengo, Leadbelly'], 'cans': [tensor([3185]), tensor([328]), tensor([1930]), tensor([2592]), tensor([1422]), tensor([3638]), tensor([1101]), tensor([1639]), tensor([1075]), tensor([1631])], 'cans_name': [('Vanessa Paradis',), ('Scooter',), ('Richard Hawley',), ('Funkadelic',), ('Maria Rita',), ('Graham Coxon',), ('B.B. King',), ('Mad Season',), ('Godspeed You! Black Emperor',), ('Screaming Trees',)], 'cans_str': ['Vanessa Paradis, Scooter, Richard Hawley, Funkadelic, Maria Rita, Graham Coxon, B.B. King, Mad Season, Godspeed You! Black Emperor, Screaming Trees'], 'len_cans': tensor([10]), 'item_id': tensor([1075]), 'item_name': ['Godspeed You! Black Emperor'], 'correct_answer': ['Godspeed You! Black Emperor'], 'most_similar_seq': [[tensor([1869]), tensor([1878]), tensor([1604]), tensor([1613]), tensor([1101]), tensor([2996]), tensor([1121]), tensor([4093]), tensor([3820]), tensor([3530])], [tensor([1561]), tensor([1317]), tensor([1869]), tensor([1878]), tensor([1604]), tensor([1613]), tensor([1101]), tensor([2996]), tensor([1121]), tensor([4093])], [tensor([3056]), tensor([1015]), tensor([3057]), tensor([2749]), tensor([1877]), tensor([3058]), tensor([3059]), tensor([2840]), tensor([1878]), tensor([1879])], [tensor([2003]), tensor([1452]), tensor([2290]), tensor([3967]), tensor([569]), tensor([2942]), tensor([1844]), tensor([975]), tensor([435]), tensor([2007])], [tensor([1015]), tensor([3057]), tensor([2749]), tensor([1877]), tensor([3058]), tensor([3059]), tensor([2840]), tensor([1878]), tensor([1879]), tensor([3060])], [tensor([1877]), tensor([3058]), tensor([3059]), tensor([2840]), tensor([1878]), tensor([1879]), tensor([3060]), tensor([1068]), tensor([3061]), tensor([1075])], [tensor([1354]), tensor([1477]), tensor([1804]), tensor([611]), tensor([555]), tensor([1805]), tensor([874]), tensor([1806]), tensor([577]), tensor([614])], [tensor([3061]), tensor([1604]), tensor([4436]), tensor([2854]), tensor([1075]), tensor([1101]), tensor([1121]), tensor([4093]), tensor([4094]), tensor([1625])], [tensor([1068]), tensor([3061]), tensor([1604]), tensor([4436]), tensor([2854]), tensor([1075]), tensor([1101]), tensor([1121]), tensor([4093]), tensor([4094])], [tensor([1317]), tensor([1869]), tensor([1878]), tensor([1604]), tensor([1613]), tensor([1101]), tensor([2996]), tensor([1121]), tensor([4093]), tensor([3820])]], 'most_similar_seq_next': [tensor([3726]), tensor([3820]), tensor([3060]), tensor([2824]), tensor([1068]), tensor([3062]), tensor([119]), tensor([3799]), tensor([1625]), tensor([3530])], 'most_similar_seq_name': [[('Sly & The Family Stone',), ('Willie Nelson',), ('Robert Johnson',), ('Jeff Beck',), ('B.B. King',), ('The Derek Trucks Band',), ('The Allman Brothers Band',), ('Freddie King',), ('Little Feat',), ('The Meters',)], [('Buddy Guy',), ('Counting Crows',), ('Sly & The Family Stone',), ('Willie Nelson',), ('Robert Johnson',), ('Jeff Beck',), ('B.B. King',), ('The Derek Trucks Band',), ('The Allman Brothers Band',), ('Freddie King',)], [('The Gun Club',), ('Sheryl Crow',), ('Spiritualized',), ('Sun City Girls',), ('Hank Williams',), ('The Flying Burrito Brothers',), ('Loretta Lynn',), ('The Band',), ('Willie Nelson',), ('Emmylou Harris',)], [('Billy Joel',), ('Peter Gabriel',), ('Mando Diao',), ('Delorean',), ('Morrissey',), ('Best Coast',), ('Paul Young',), ('Foals',), ('Elvis Costello',), ('Paul Simon',)], [('Sheryl Crow',), ('Spiritualized',), ('Sun City Girls',), ...
